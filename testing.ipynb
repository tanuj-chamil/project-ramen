# %%
from spectrum import *
import pandas as pd

# %%
file_path = "databases\\csv\\galactosamine.csv"
data = pd.read_csv(file_path)

molecule =  Spectrum('adenine', data['L'], data['I'])

# %%
molecule.plot()

# %%
molecule.denoise(polyorder=7,section_size=5)
molecule.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10636\1407146475.py in <module>
# ----> 1 molecule.denoise(polyorder=9)
#       2 molecule.plot()
#
# e:\Academic\Semester 05\Charaterization\codebase\project-ramen\spectrum.py in denoise(self, polyorder, section_size)
#      31             section_size (int, optional): convoluting section size. Defaults to 7.
#      32         """
# ---> 33         self.intensity = sgf(self.intensity,window_length=section_size, polyorder=polyorder)
#      34         return self
#      35
#
# c:\Users\Tanuj\anaconda3\lib\site-packages\scipy\signal\_savitzky_golay.py in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     338         x = x.astype(np.float64)
#     339
# --> 340     coeffs = savgol_coeffs(window_length, polyorder, deriv=deriv, delta=delta)
#     341
# ...

# %%
molecule.correct_baseline(polyorder=6)
molecule.plot()

# %%
molecule.min_max_normalize()
molecule.plot()
